# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import time
from IPython.display import clear_output

# %% [markdown]
# ## Load Map

# %%
CHAR_MAPPING = {
    "x" : -1,
    "." : 0,
    "H" : 1,
    "h" : 2, 
    "s": 3
}
COLOR_MAPPING = ["black", "white", "blue", "green", "red"]
MAP_SIMPLE_NAME = "map.txt"

def load_map(mapname, char_mapping):
    with open(mapname, 'r') as map_file:
        lines = map_file.readlines()
        # width = int(lines[0])
        # height = int(lines[1])
        map_numbers = [[char_mapping[chr] for chr in row[:-1]] for row in lines[2:]]
    return np.array(map_numbers, dtype = np.int32)

simple_map = load_map(MAP_SIMPLE_NAME, CHAR_MAPPING)
hider_pos = np.asarray(np.where(simple_map == CHAR_MAPPING["h"])).reshape(2)
seeker_pos = np.asarray(np.where(simple_map == CHAR_MAPPING["s"])).reshape(2)
#start configuration
MAP_START = np.copy(simple_map)
MAP_START[hider_pos[0], hider_pos[1]] = CHAR_MAPPING["."]
MAP_START[seeker_pos[0], seeker_pos[1]] = CHAR_MAPPING["."]

# %% [markdown]
# ## Map visualization

# %%
def plot_map_jupiter_notebook(map, _):
    clear_output(wait=True)
    plt.figure()
    plt.imshow(map , cmap = matplotlib.colors.ListedColormap(COLOR_MAPPING))
    plt.show()
    
class Map_plot:
    def __init__(self):
        plt.ion()
        self.fig, self.ax = plt.subplots()
        self.img = self.ax.imshow(simple_map , cmap = matplotlib.colors.ListedColormap(COLOR_MAPPING))
        
    def plot_map(self,map):
        self.img.set_array(map)
        plt.draw()
        self.img.canvas.flush_events()

class Map_log:
    def __init__(self, log_name):
        self.log_name = log_name
        self.log_num = 0 
        
    def log_map(self,map):
        pass

# %%
def get_percepts(map_env, pos, agent = "h"):
    VISION = 1
    return map_env [pos[0] - VISION : pos[0] + VISION + 1, pos[1] - VISION : pos[1] + VISION + 1]

ACTIONS = [[-1,0], [1, 0], [0, -1], [0, 1]]

def is_free(map_env, pos, agent):
    if (agent == "h"):
        return map_env[pos[0], pos[1]] in [CHAR_MAPPING["."], CHAR_MAPPING["H"], CHAR_MAPPING["h"]]
    return ((map_env[pos[0], pos[1]] in [CHAR_MAPPING["."], CHAR_MAPPING["s"]]) or 
        (map_env[pos[0], pos[1]] == CHAR_MAPPING["h"] and MAP_START[pos[0], pos[1]] != CHAR_MAPPING["H"]))


def do_action(map_env, pos, action, agent):
    new_pos = pos + ACTIONS[action]
    #print("ACTION")
    #print(pos)
    #print(ACTIONS[action])
    #print(new_pos)
    #print(new_pos)
    if is_free(map_env, new_pos, agent):
        #print(True)
        map_env[new_pos[0], new_pos[1]] = CHAR_MAPPING[agent]
        map_env[pos[0], pos[1]] = MAP_START[pos[0], pos[1]]
        return map_env, new_pos
    else:
        return map_env, pos




def simulate_step(map_env, pos_hide, pos_seek, policy_hide, policy_seek, **kwargs):

    action_seek = policy_seek(get_percepts(map_env, pos_seek, "s"), agent = "s", pos_hide = pos_hide, pos_seek = pos_seek, map_env = map_env, **kwargs )
    map_env, new_pos_seek = do_action(map_env, pos_seek, action_seek, "s")
    if(is_end(map_env, pos_hide, new_pos_seek)):
        return (map_env, pos_hide, new_pos_seek)        
    action_hide = policy_hide(get_percepts(map_env, pos_hide, "h"), agent = "h", pos_hide = pos_hide, pos_seek = pos_seek, map_env = map_env, **kwargs)
    map_env, new_pos_hide = do_action(map_env, pos_hide, action_hide, "h")
    #print(new_pos_hide, new_pos_seek)
    return (map_env, new_pos_hide, new_pos_seek)  #TODO add state


def eval_map_state(map_env, pos_hide, pos_seek):
    #TODO
    if MAP_START[pos_hide[0], pos_hide[1]] == CHAR_MAPPING["H"]:
        state_hide = 0
    elif np.all(pos_hide == pos_seek):
        state_hide = -100000
    elif np.abs(pos_hide - pos_seek).sum() == 1:
        state_hide = -500
    else:
        state_hide = pos_hide[0] **2 + pos_hide[1] ** 2

    if np.all(pos_hide == pos_seek):
        state_seek = 100000
    elif np.abs((pos_hide - pos_seek)).sum() == 1:
        state_seek = 500
    else:
        state_seek = 0
    return (state_hide, state_seek)

def is_end(map_env, pos_hide, pos_seek):
    return np.all(pos_hide == pos_seek)

def simulate(map_orig, start_hide, start_seek, policy_hide, policy_seek, plot_func, num_steps = 100, **kwargs):
    pos_hide, pos_seek = start_hide, start_seek
    SEEK_STATE = 0
    HIDE_STATE = 0
    map_env = np.copy(map_orig)
    scores = np.zeros(2)
    for step in range(num_steps):
        map_env, pos_hide, pos_seek = simulate_step(map_env, pos_hide, pos_seek, policy_hide, policy_seek, **kwargs)
        #time.sleep(0.2)
        if kwargs.get("plot") == True:
            plot_func(map_env, kwargs.get("generation"))
        scores += eval_map_state(map_env, pos_hide, pos_seek)
        scores += [600, -600]  #longer game is good for hider, shorter good for seeker
        if(is_end(map_env, pos_hide, pos_seek)):
            break
    return scores

def random_policy(percepts, agent, **kwargs):
    return np.random.randint(len(ACTIONS))
#print(simple_map)

simulate(simple_map, hider_pos, seeker_pos, random_policy, random_policy, plot_map_jupiter_notebook, generation = 1, num_steps=50, plot = True)
# Out:
# array([-88931.,  89700.])

# %%
import neat
STATE_SEEK = 0
def NN_policy(percepts, agent, **kwargs):
    perc_flat = percepts.reshape(-1)
    #ONE HOT ENCODING TRY
    #for percept in percepts.reshape(-1):
    #    perc_index = list(CHAR_MAPPING.values()).index(percept)
    #    one_hot_single = [0] * len(COLOR_MAPPING)
    #    one_hot_single[perc_index] = 1
    #    one_hot_input.extend(one_hot_single)
    one_hot_in = np.zeros((len(perc_flat), len(COLOR_MAPPING)))
    one_hot_in[np.arange(len(perc_flat)), perc_flat + 1] = 1

    if agent == "h":
        network = kwargs.get("hide_net")
        pos = kwargs.get("pos_hide")
        
    else:
        network = kwargs.get("seek_net")
        pos = kwargs.get("pos_seek")
    output = np.copy(network.activate(one_hot_in.reshape(-1)))
    #output = np.copy(network.activate(percepts.reshape(-1)/3))
    action = np.argmax(output)
    new_pos = pos + ACTIONS[action]
    #print(new_pos)
    #print(agent)
    while not is_free(kwargs.get("map_env"), new_pos, agent):
        #print("NOT_FREE")
        #print(np.argmax(output))
        output[np.argmax(output)] = -np.inf
        new_pos = pos + ACTIONS[np.argmax(output)]
        #print(pos)
        #print("-")
    #print("CHOSEN")
    #print(np.argmax(output))
    return np.argmax(output)

# %%
#todo fic parttools last two arguments
import functools
import os
FIT_SIMULATION_STEPS = 40
INTER_IT_COUNT = 20
POP_LEN = 20

def fitness_seek(genomes, config, start_hide, start_seek, default_map_state, hide_net):
    #print("FITNESS SEEK")
    for genome_id, genome in genomes:        
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        genome.fitness = simulate(default_map_state, start_hide, 
            start_seek, NN_policy, NN_policy, plot_map_jupiter_notebook,
            num_steps = FIT_SIMULATION_STEPS, 
            seek_net = net, 
            hide_net = neat.nn.FeedForwardNetwork.create(hide_net, config), plot = False)[1]

def fitness_hide(genomes, config, start_hide, start_seek, default_map_state, seek_net):
    #print("FITNESS HIDE")
    for genome_id, genome in genomes:        
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        genome.fitness = simulate(default_map_state, start_hide, 
            start_seek, NN_policy, NN_policy, plot_map_jupiter_notebook,
            num_steps = FIT_SIMULATION_STEPS, 
            seek_net = neat.nn.FeedForwardNetwork.create(seek_net, config), 
            hide_net = net, plot = False)[0]

def run_evolution(config_file, map_env, start_hide, start_seek,  main_it_count = 80):
    # Load configuration.
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)

    # Create the population, which is the top-level object for a NEAT run.
    seek_pop = neat.Population(config)
    seek_pop.add_reporter(neat.StdOutReporter(True))
    stats_s = neat.StatisticsReporter()
    seek_pop.add_reporter(stats_s)
    seek_pop.add_reporter(neat.Checkpointer(INTER_IT_COUNT))

    hide_pop = neat.Population(config)
    hide_pop.add_reporter(neat.StdOutReporter(True))
    stats_h = neat.StatisticsReporter()
    hide_pop.add_reporter(stats_h)
    hide_pop.add_reporter(neat.Checkpointer(INTER_IT_COUNT))
    #TODO how to init winner
    winner_seek = neat.DefaultGenome(config)
    winner_hide = neat.DefaultGenome(config)

    for it in range(main_it_count):
        
        # Run for up to 300 generations.
        
        fit_seek_fixed = functools.partial(fitness_seek, default_map_state = map_env, start_hide = start_hide, 
            start_seek = start_seek, hide_net = winner_hide)
        winner_seek = seek_pop.run(fit_seek_fixed, INTER_IT_COUNT)
        #TODO how to return whole population ?
        seek_pop = neat.checkpoint.Checkpointer.restore_checkpoint("neat-checkpoint-" + str( INTER_IT_COUNT - 1) )
        seek_pop.add_reporter(neat.StdOutReporter(True))
        stats_s = neat.StatisticsReporter()
        seek_pop.add_reporter(stats_s)

        fit_hide_fixed = functools.partial(fitness_hide, default_map_state = map_env, start_hide = start_hide, 
            start_seek = start_seek, seek_net = winner_seek)
        winner_hide = hide_pop.run(fit_hide_fixed, INTER_IT_COUNT)
        #TODO how to return whole population ?
        #hide_pop = stats_h.best_unique_genomes(POP_LEN)
        hide_pop = neat.checkpoint.Checkpointer.restore_checkpoint("neat-checkpoint-" + str( INTER_IT_COUNT - 1) )
        hide_pop.add_reporter(neat.StdOutReporter(True))
        stats_h = neat.StatisticsReporter()
        hide_pop.add_reporter(stats_h)
        
    return (winner_hide, winner_seek, config)  
    

config_path = 'config-feedforward'
winner_hide, winner_seek, config = run_evolution(config_path, simple_map, hider_pos, seeker_pos)
#
    ##TODO adjust below
    ## Display the winning genome.
    #print('\nBest genome:\n{!s}'.format(winner))
#
    ## Show output of the most fit genome against training data.
    #print('\nOutput:')
    #winner_net = neat.nn.FeedForwardNetwork.create(winner, config)
    ##for xi, xo in zip(xor_inputs, xor_outputs):
    ##    output = winner_net.activate(xi)
    ##    print("input {!r}, expected output {!r}, got {!r}".format(xi, xo, output))
#
    #node_names = {-1: 'A', -2: 'B', 0: 'A XOR B'}
    #visualize.draw_net(config, winner, True, node_names=node_names)
    #visualize.draw_net(config, winner, True, node_names=node_names, prune_unused=True)
    #visualize.plot_stats(stats, ylog=False, view=True)
    #visualize.plot_species(stats, view=True)
#
    #p = neat.Checkpointer.restore_checkpoint('neat-checkpoint-4')
    #p.run(eval_genomes, 10)
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.958, standard deviation 0.300
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    20  -24000.0    0.000     0
# Total extinctions: 0
# Generation time: 0.341 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.884, standard deviation 0.320
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    20  -24000.0    0.000     1
# Total extinctions: 0
# Generation time: 0.177 sec (0.259 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.844, standard deviation 0.302
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2    20  -24000.0    0.000     2
# Total extinctions: 0
# Generation time: 0.241 sec (0.253 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.892, standard deviation 0.274
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3    20  -24000.0    0.000     3
# Total extinctions: 0
# Generation time: 0.346 sec (0.276 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.834, standard deviation 0.293
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    20  -24000.0    0.000     4
# Total extinctions: 0
# Generation time: 0.359 sec (0.293 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.925, standard deviation 0.284
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5    20  -24000.0    0.000     5
# Total extinctions: 0
# Generation time: 0.388 sec (0.309 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.043, standard deviation 0.261
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6    20  -24000.0    0.000     6
# Total extinctions: 0
# Generation time: 0.502 sec (0.336 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.017, standard deviation 0.287
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7    20  -24000.0    0.000     7
# Total extinctions: 0
# Generation time: 0.320 sec (0.334 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.895, standard deviation 0.282
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8    20  -24000.0    0.000     8
# Total extinctions: 0
# Generation time: 0.388 sec (0.340 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.048, standard deviation 0.264
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    20  -24000.0    0.000     9
# Total extinctions: 0
# Generation time: 0.241 sec (0.330 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.876, standard deviation 0.325
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    20  -24000.0    0.000    10
# Total extinctions: 0
# Generation time: 0.369 sec (0.333 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.033, standard deviation 0.265
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    20  -24000.0    0.000    11
# Total extinctions: 0
# Generation time: 0.499 sec (0.365 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.037, standard deviation 0.292
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    20  -24000.0    0.000    12
# Total extinctions: 0
# Generation time: 0.297 sec (0.371 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.011, standard deviation 0.342
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    20  -24000.0    0.000    13
# Total extinctions: 0
# Generation time: 0.160 sec (0.352 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.051, standard deviation 0.259
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14    20  -24000.0    0.000    14
# Total extinctions: 0
# Generation time: 0.284 sec (0.345 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.971, standard deviation 0.330
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15    20  -24000.0    0.000    15
# Total extinctions: 0
# Generation time: 0.376 sec (0.344 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.072, standard deviation 0.298
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16    20  -24000.0    0.000    16
# Total extinctions: 0
# Generation time: 0.259 sec (0.319 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.913, standard deviation 0.282
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17    20  -24000.0    0.000    17
# Total extinctions: 0
# Generation time: 0.210 sec (0.308 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.038, standard deviation 0.246
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18    20  -24000.0    0.000    18
# Total extinctions: 0
# Generation time: 0.219 sec (0.292 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.914, standard deviation 0.295
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19    20  -24000.0    0.000    19
# Total extinctions: 0
# Generation time: 0.258 sec (0.293 average)
# Saving checkpoint to neat-checkpoint-19
#
#  ****** Running generation 0 ******
#
# Population's average fitness: 25802.90000 stdev: 576.77672
# Best fitness: 26648.00000 - size: (4, 180) - species 1 - id 2
# Average adjusted fitness: 0.666
# Mean genetic distance 1.134, standard deviation 0.178
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    20  26648.0    0.666     0
# Total extinctions: 0
# Generation time: 0.284 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 26385.60000 stdev: 726.46283
# Best fitness: 27702.00000 - size: (4, 178) - species 1 - id 21
# Average adjusted fitness: 0.549
# Mean genetic distance 1.043, standard deviation 0.195
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    20  27702.0    0.549     0
# Total extinctions: 0
# Generation time: 0.348 sec (0.316 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 26544.90000 stdev: 675.58759
# Best fitness: 27702.00000 - size: (4, 178) - species 1 - id 21
# Average adjusted fitness: 0.529
# Mean genetic distance 1.015, standard deviation 0.296
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2    20  27702.0    0.529     1
# Total extinctions: 0
# Generation time: 0.437 sec (0.356 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 26935.50000 stdev: 650.37339
# Best fitness: 27702.00000 - size: (4, 178) - species 1 - id 21
# Average adjusted fitness: 0.533
# Mean genetic distance 0.969, standard deviation 0.330
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3    20  27702.0    0.533     2
# Total extinctions: 0
# Generation time: 0.330 sec (0.350 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 27267.30000 stdev: 570.60749
# Best fitness: 27702.00000 - size: (4, 178) - species 1 - id 21
# Average adjusted fitness: 0.753
# Mean genetic distance 1.139, standard deviation 0.349
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    20  27702.0    0.753     3
# Total extinctions: 0
# Generation time: 0.429 sec (0.366 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 27147.10000 stdev: 763.58614
# Best fitness: 28104.00000 - size: (4, 174) - species 1 - id 97
# Average adjusted fitness: 0.574
# Mean genetic distance 1.158, standard deviation 0.228
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5    20  28104.0    0.574     0
# Total extinctions: 0
# Generation time: 0.252 sec (0.347 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 27251.20000 stdev: 805.08221
# Best fitness: 28104.00000 - size: (4, 174) - species 1 - id 97
# Average adjusted fitness: 0.626
# Mean genetic distance 1.074, standard deviation 0.234
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6    20  28104.0    0.626     1
# Total extinctions: 0
# Generation time: 0.229 sec (0.330 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 27396.80000 stdev: 769.91802
# Best fitness: 28104.00000 - size: (4, 174) - species 1 - id 97
# Average adjusted fitness: 0.690
# Mean genetic distance 0.887, standard deviation 0.190
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7    20  28104.0    0.690     2
# Total extinctions: 0
# Generation time: 0.378 sec (0.336 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 27533.10000 stdev: 671.44455
# Best fitness: 28104.00000 - size: (4, 169) - species 1 - id 129
# Average adjusted fitness: 0.736
# Mean genetic distance 0.692, standard deviation 0.197
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8    20  28104.0    0.736     3
# Total extinctions: 0
# Generation time: 0.358 sec (0.338 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 27137.30000 stdev: 764.03096
# Best fitness: 28104.00000 - size: (4, 169) - species 1 - id 129
# Average adjusted fitness: 0.576
# Mean genetic distance 0.810, standard deviation 0.200
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    20  28104.0    0.576     4
# Total extinctions: 0
# Generation time: 0.478 sec (0.352 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 27534.60000 stdev: 669.37347
# Best fitness: 28104.00000 - size: (4, 169) - species 1 - id 129
# Average adjusted fitness: 0.737
# Mean genetic distance 0.732, standard deviation 0.244
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    20  28104.0    0.737     5
# Total extinctions: 0
# Generation time: 0.416 sec (0.366 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 27382.00000 stdev: 754.88701
# Best fitness: 28104.00000 - size: (4, 169) - species 1 - id 129
# Average adjusted fitness: 0.666
# Mean genetic distance 0.834, standard deviation 0.244
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    20  28104.0    0.666     6
# Total extinctions: 0
# Generation time: 0.285 sec (0.359 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 27567.50000 stdev: 644.08909
# Best fitness: 28104.00000 - size: (4, 169) - species 1 - id 129
# Average adjusted fitness: 0.752
# Mean genetic distance 0.805, standard deviation 0.295
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    20  28104.0    0.752     7
# Total extinctions: 0
# Generation time: 0.378 sec (0.353 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 27269.00000 stdev: 742.79755
# Best fitness: 28104.00000 - size: (4, 169) - species 1 - id 129
# Average adjusted fitness: 0.614
# Mean genetic distance 0.861, standard deviation 0.290
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    20  28104.0    0.614     8
# Total extinctions: 0
# Generation time: 0.321 sec (0.352 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 27656.90000 stdev: 512.45467
# Best fitness: 28104.00000 - size: (4, 169) - species 1 - id 129
# Average adjusted fitness: 0.699
# Mean genetic distance 0.803, standard deviation 0.260
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14    20  28104.0    0.699     9
# Total extinctions: 0
# Generation time: 0.459 sec (0.355 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 27294.70000 stdev: 798.10633
# Best fitness: 28104.00000 - size: (4, 169) - species 1 - id 129
# Average adjusted fitness: 0.639
# Mean genetic distance 0.866, standard deviation 0.267
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15    20  28104.0    0.639    10
# Total extinctions: 0
# Generation time: 0.323 sec (0.363 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 27557.60000 stdev: 670.36217
# Best fitness: 28104.00000 - size: (4, 169) - species 1 - id 129
# Average adjusted fitness: 0.748
# Mean genetic distance 0.843, standard deviation 0.285
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16    20  28104.0    0.748    11
# Total extinctions: 0
# Generation time: 0.438 sec (0.383 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 27315.40000 stdev: 870.62646
# Best fitness: 28104.00000 - size: (4, 169) - species 1 - id 129
# Average adjusted fitness: 0.693
# Mean genetic distance 0.945, standard deviation 0.244
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17    20  28104.0    0.693    12
# Total extinctions: 0
# Generation time: 0.441 sec (0.390 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 27816.30000 stdev: 346.27635
# Best fitness: 28104.00000 - size: (4, 169) - species 1 - id 129
# Average adjusted fitness: 0.806
# Mean genetic distance 0.875, standard deviation 0.295
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18    20  28104.0    0.806    13
# Total extinctions: 0
# Generation time: 0.430 sec (0.397 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 27542.50000 stdev: 689.08748
# Best fitness: 28104.00000 - size: (4, 169) - species 1 - id 129
# Average adjusted fitness: 0.754
# Mean genetic distance 0.833, standard deviation 0.219
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19    20  28104.0    0.754    14
# Total extinctions: 0
# Generation time: 0.501 sec (0.399 average)
# Saving checkpoint to neat-checkpoint-19
#
#  ****** Running generation 19 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 180) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.932, standard deviation 0.220
# Population of 19 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19    19  -24000.0    0.000    19
# Total extinctions: 0
# Generation time: 0.537 sec
#
#  ****** Running generation 20 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 178) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.108, standard deviation 0.255
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20    20  -24000.0    0.000    20
# Total extinctions: 0
# Generation time: 0.339 sec (0.438 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 177) - species 1 - id 10
# Average adjusted fitness: 0.000
# Mean genetic distance 0.925, standard deviation 0.312
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21    20  -24000.0    0.000    21
# Total extinctions: 0
# Generation time: 0.334 sec (0.403 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 177) - species 1 - id 10
# Average adjusted fitness: 0.000
# Mean genetic distance 0.989, standard deviation 0.291
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22    20  -24000.0    0.000    22
# Total extinctions: 0
# Generation time: 0.401 sec (0.403 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 177) - species 1 - id 10
# Average adjusted fitness: 0.000
# Mean genetic distance 0.971, standard deviation 0.350
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23    20  -24000.0    0.000    23
# Total extinctions: 0
# Generation time: 0.421 sec (0.406 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 177) - species 1 - id 10
# Average adjusted fitness: 0.000
# Mean genetic distance 0.917, standard deviation 0.307
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24    20  -24000.0    0.000    24
# Total extinctions: 0
# Generation time: 0.473 sec (0.417 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 177) - species 1 - id 10
# Average adjusted fitness: 0.000
# Mean genetic distance 0.821, standard deviation 0.273
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25    20  -24000.0    0.000    25
# Total extinctions: 0
# Generation time: 0.365 sec (0.410 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 177) - species 1 - id 10
# Average adjusted fitness: 0.000
# Mean genetic distance 0.943, standard deviation 0.278
# Population of 19 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26    19  -24000.0    0.000    26
# Total extinctions: 0
# Generation time: 0.431 sec (0.413 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 177) - species 1 - id 10
# Average adjusted fitness: 0.000
# Mean genetic distance 0.881, standard deviation 0.373
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27    20  -24000.0    0.000    27
# Total extinctions: 0
# Generation time: 0.259 sec (0.395 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 177) - species 1 - id 10
# Average adjusted fitness: 0.000
# Mean genetic distance 1.036, standard deviation 0.353
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28    20  -24000.0    0.000    28
# Total extinctions: 0
# Generation time: 0.268 sec (0.383 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 177) - species 1 - id 10
# Average adjusted fitness: 0.000
# Mean genetic distance 0.893, standard deviation 0.327
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29    20  -24000.0    0.000    29
# Total extinctions: 0
# Generation time: 0.332 sec (0.362 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 177) - species 1 - id 10
# Average adjusted fitness: 0.000
# Mean genetic distance 1.100, standard deviation 0.373
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30    20  -24000.0    0.000    30
# Total extinctions: 0
# Generation time: 0.225 sec (0.351 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: -24000.00000 stdev: 0.00000
# Best fitness: -24000.00000 - size: (4, 177) - species 1 - id 10
# Average adjusted fitness: 0.000
# Mean genetic distance 0.977, standard deviation 0.368
# Population of 20 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31    20  -24000.0    0.000    31
# Total extinctions: 0
# Generation time: 0.570 sec (0.374 average)
#
#  ****** Running generation 32 ******
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25900/4096086100.py in <module>
#      75
#      76 config_path = 'config-feedforward'
# ---> 77 winner_hide, winner_seek, config = run_evolution(config_path, simple_map, hider_pos, seeker_pos)
#      78 #
#      79     ##TODO adjust below
#
# ~\AppData\Local\Temp/ipykernel_25900/4096086100.py in run_evolution(config_file, map_env, start_hide, start_seek, main_it_count)
#      54         fit_seek_fixed = functools.partial(fitness_seek, default_map_state = map_env, start_hide = start_hide,
#      55             start_seek = start_seek, hide_net = winner_hide)
# ---> 56         winner_seek = seek_pop.run(fit_seek_fixed, INTER_IT_COUNT)
#      57         #TODO how to return whole population ?
#      58         seek_pop = neat.checkpoint.Checkpointer.restore_checkpoint("neat-checkpoint-" + str( INTER_IT_COUNT - 1) )
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\neat\population.py in run(self, fitness_function, n)
#      87
#      88             # Evaluate all genomes using the user-provided function.
# ---> 89             fitness_function(list(iteritems(self.population)), self.config)
#      90
#      91             # Gather and report statistics.
#
# ~\AppData\Local\Temp/ipykernel_25900/4096086100.py in fitness_seek(genomes, config, start_hide, start_seek, default_map_state, hide_net)
#      10     for genome_id, genome in genomes:
#      11         net = neat.nn.FeedForwardNetwork.create(genome, config)
# ---> 12         genome.fitness = simulate(default_map_state, start_hide,
#      13             start_seek, NN_policy, NN_policy, plot_map_jupiter_notebook,
#      14             num_steps = FIT_SIMULATION_STEPS,
#
# ~\AppData\Local\Temp/ipykernel_25900/797393082.py in simulate(map_orig, start_hide, start_seek, policy_hide, policy_seek, plot_func, num_steps, **kwargs)
#      71     scores = np.zeros(2)
#      72     for step in range(num_steps):
# ---> 73         map_env, pos_hide, pos_seek = simulate_step(map_env, pos_hide, pos_seek, policy_hide, policy_seek, **kwargs)
#      74         #time.sleep(0.2)
#      75         if kwargs.get("plot") == True:
#
# ~\AppData\Local\Temp/ipykernel_25900/797393082.py in simulate_step(map_env, pos_hide, pos_seek, policy_hide, policy_seek, **kwargs)
#      32 def simulate_step(map_env, pos_hide, pos_seek, policy_hide, policy_seek, **kwargs):
#      33
# ---> 34     action_seek = policy_seek(get_percepts(map_env, pos_seek, "s"), agent = "s", pos_hide = pos_hide, pos_seek = pos_seek, map_env = map_env, **kwargs )
#      35     map_env, new_pos_seek = do_action(map_env, pos_seek, action_seek, "s")
#      36     if(is_end(map_env, pos_hide, new_pos_seek)):
#
# ~\AppData\Local\Temp/ipykernel_25900/2670489126.py in NN_policy(percepts, agent, **kwargs)
#      10     #    one_hot_input.extend(one_hot_single)
#      11     one_hot_in = np.zeros((len(perc_flat), len(COLOR_MAPPING)))
# ---> 12     one_hot_in[np.arange(len(perc_flat)), perc_flat + 1] = 1
#      13
#      14     if agent == "h":
#
# KeyboardInterrupt:

# %%
import warnings

import graphviz
import matplotlib.pyplot as plt
import numpy as np
def draw_net(config, genome, view=False, filename=None, node_names=None, show_disabled=True, prune_unused=False,
             node_colors=None, fmt='svg'):
    """ Receives a genome and draws a neural network with arbitrary topology. """
    # Attributes for network nodes.
    if graphviz is None:
        warnings.warn("This display is not available due to a missing optional dependency (graphviz)")
        return

    # If requested, use a copy of the genome which omits all components that won't affect the output.
    if prune_unused:
        genome = genome.get_pruned_copy(config.genome_config)

    if node_names is None:
        node_names = {}

    assert type(node_names) is dict

    if node_colors is None:
        node_colors = {}

    assert type(node_colors) is dict

    node_attrs = {
        'shape': 'circle',
        'fontsize': '9',
        'height': '0.2',
        'width': '0.2'}

    dot = graphviz.Digraph(format=fmt, node_attr=node_attrs)

    inputs = set()
    for k in config.genome_config.input_keys:
        inputs.add(k)
        name = node_names.get(k, str(k))
        input_attrs = {'style': 'filled', 'shape': 'box', 'fillcolor': node_colors.get(k, 'lightgray')}
        dot.node(name, _attributes=input_attrs)

    outputs = set()
    for k in config.genome_config.output_keys:
        outputs.add(k)
        name = node_names.get(k, str(k))
        node_attrs = {'style': 'filled', 'fillcolor': node_colors.get(k, 'lightblue')}

        dot.node(name, _attributes=node_attrs)

    used_nodes = set(genome.nodes.keys())
    for n in used_nodes:
        if n in inputs or n in outputs:
            continue

        attrs = {'style': 'filled',
                 'fillcolor': node_colors.get(n, 'white')}
        dot.node(str(n), _attributes=attrs)

    for cg in genome.connections.values():
        if cg.enabled or show_disabled:
            # if cg.input not in used_nodes or cg.output not in used_nodes:
            #    continue
            input, output = cg.key
            a = node_names.get(input, str(input))
            b = node_names.get(output, str(output))
            style = 'solid' if cg.enabled else 'dotted'
            color = 'green' if cg.weight > 0 else 'red'
            width = str(0.1 + abs(cg.weight / 5.0))
            dot.edge(a, b, _attributes={'style': style, 'color': color, 'penwidth': width})

    dot.render(filename, view=view)

    return dot

# %%
import visualize
res = draw_net(config, winner_hide, True)

# %%
simulate(simple_map, hider_pos, seeker_pos, random_policy, random_policy, generation = 1, num_steps=50, plot = True)
# Out:
# array([ 34268., -30000.])

# %%
simulate(simple_map, hider_pos, seeker_pos, 
        NN_policy, NN_policy, num_steps=100,
        hide_net = neat.nn.FeedForwardNetwork.create(winner_hide, config), 
        seek_net = neat.nn.FeedForwardNetwork.create(winner_seek, config),  generation = INTER_IT_COUNT * 20, plot = True)
# Out:
# array([ 70494., -60000.])
